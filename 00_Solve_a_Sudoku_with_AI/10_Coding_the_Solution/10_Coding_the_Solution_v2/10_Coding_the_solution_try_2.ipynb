# %%
from utils import *

values = {'A4': '123456789', 'D8': '6', 'F9': '123456789', 'F3': '123456789', 'H5': '123456789', 'D1': '123456789', 'A1': '4', 'B4': '123456789', 'I2': '123456789', 'G2': '123456789', 'H9': '123456789', 'G3': '123456789', 'A8': '123456789', 'E2': '123456789', 'E5': '8', 'G8': '7', 'G7': '123456789', 'E7': '4', 'I4': '123456789', 'I8': '123456789', 'E1': '123456789', 'C1': '123456789', 'G9': '123456789', 'H6': '123456789', 'C6': '123456789', 'E9': '123456789', 'D6': '123456789', 'A5': '123456789', 'G5': '123456789', 'G4': '6', 'B9': '123456789', 'C3': '123456789', 'B6': '123456789', 'B7': '123456789', 'C2': '123456789', 'I3': '4', 'D5': '123456789', 'F5': '1', 'B1': '123456789', 'B2': '3', 'D9': '123456789', 'C7': '123456789', 'G6': '3', 'I5': '123456789', 'A3': '123456789', 'B5': '123456789', 'D7': '123456789', 'C8': '123456789', 'H3': '123456789', 'I1': '1', 'H1': '5', 'A2': '123456789', 'B3': '123456789', 'F4': '123456789', 'H2': '123456789', 'H8': '123456789', 'I6': '123456789', 'F7': '123456789', 'C4': '7', 'D3': '123456789', 'H7': '123456789', 'C5': '123456789', 'E6': '123456789', 'D4': '123456789', 'B8': '123456789', 'I9': '123456789', 'G1': '123456789', 'A7': '8', 'A9': '5', 'F8': '123456789', 'F6': '123456789', 'I7': '123456789', 'E4': '123456789', 'H4': '2', 'F1': '123456789', 'A6': '123456789', 'D2': '2', 'F2': '123456789', 'E3': '123456789', 'E8': '123456789', 'C9': '123456789'}

def search(values):
    print('values')
    print(values)
    "Using depth-first search and propagation, create a search tree and solve the sudoku."
    # First, reduce the puzzle using the previous function
    values = reduce_puzzle(values)
    # Choose one of the unfilled squares with the fewest possibilities
    unfilledSquares = [box for box in values.keys() if len(values[box]) > 1]
    #unfilledSquares_Values = [value for value in values[unfilledSquares]]
    unfilledSquares_Values = []
    for square in unfilledSquares:
        unfilledSquares_Values.append(values[square])
    
    #X = ["a", "b", "c", "d", "e", "f", "g", "h", "i"]
    #Y = [ 0,   1,   1,    0,   1,   2,   2,   0,   1]

    sorted_y_idx_list = sorted(range(len(unfilledSquares)),key=lambda x:unfilledSquares_Values[x])
    Xs = [unfilledSquares_Values[i] for i in sorted_y_idx_list ]
    
    print('values')
    print(values)
    print('unfilledSquares')
    print(unfilledSquares)
    print('unfilledSquares_Values')
    print(unfilledSquares_Values)
    print('sorted_y_idx_list')
    print(sorted_y_idx_list)
    print('Xs')
    print(Xs)
    # Now use recursion to solve each one of the resulting sudokus, and if one returns a value (not False), return that answer!
    if len(unfilledSquares) == 0:
        return values
    # If you're stuck, see the solution.py tab!

search(values)
# Out:
# values
# ...
